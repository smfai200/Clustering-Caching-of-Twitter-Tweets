# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
project = os.path.realpath('./..')
datadir = os.path.join(project, 'results\Latency\cached')
datadir = os.path.join(datadir,'responsetable.csv')
df = pd.read_csv(datadir)

# %%
df.columns
df.index
# Out:
# RangeIndex(start=0, stop=1800, step=1)

# %%
df.head()
# Out:
#       timeStamp  elapsed         label responseCode responseMessage  \
# 0  1.554040e+12      694  HTTP Request          200              OK
# 1  1.554040e+12      293  HTTP Request          200              OK
# 2  1.554040e+12      297  HTTP Request          200              OK
# 3  1.554040e+12      290  HTTP Request          200              OK
# 4  1.554040e+12      293  HTTP Request          200              OK
#
#          threadName dataType  success  failureMessage  bytes  sentBytes  \
# 0  Thread Group 1-1     text     True             NaN  12914        121
# 1  Thread Group 1-1     text     True             NaN  12883        121
# 2  Thread Group 1-1     text     True             NaN  12891        121
# 3  Thread Group 1-1     text     True             NaN  12914        121
# 4  Thread Group 1-1     text     True             NaN  12884        121
#
#    grpThreads  allThreads                           URL  Latency  IdleTime  \
# ...

# %%
df.describe()
# Out:
#           timeStamp      elapsed  failureMessage         bytes    sentBytes  \
# count  1.800000e+03  1800.000000             0.0   1800.000000  1800.000000
# mean   1.554040e+12   360.494444             NaN  12866.301111   120.663889
# std    0.000000e+00   180.605765             NaN    536.040465     6.370166
# min    1.554040e+12    56.000000             NaN   2859.000000     0.000000
# 25%    1.554040e+12   279.000000             NaN  12868.000000   121.000000
# 50%    1.554040e+12   296.000000             NaN  12886.000000   121.000000
# 75%    1.554040e+12   412.250000             NaN  12904.000000   121.000000
# max    1.554040e+12  3464.000000             NaN  13854.000000   121.000000
#
#         grpThreads   allThreads      Latency  IdleTime      Connect
# count  1800.000000  1800.000000  1800.000000    1800.0  1800.000000
# mean      4.624444     4.624444   322.386667       0.0    41.310556
# std       0.898434     0.898434   165.612131       0.0   143.597961
# ...

# %%
#Latency
#Latency is a difference between time when request was sent and time when response has started to be received.
plt.xlabel('Request Number')
plt.ylabel('Latency')
plt.plot(range(0,1800),'Latency', data=df, marker='o', markerfacecolor='blue', markersize=4, color='skyblue', linewidth=4)
plt.show()
df.sort_values(by='Latency',inplace=True, ascending=False)
plt.plot('Latency','Latency', data=df, marker='o', markerfacecolor='grey', markersize=1, color='grey', linewidth=3,linestyle='dashed')

# %%
#ConnectTime
plt.xlabel('Request Number')
plt.ylabel('Connect Time')
plt.plot( range(0,1800),'Connect', data=df, marker='o', markerfacecolor='black', markersize=4, color='grey', linewidth=4)

# %%
#ConnectTime
plt.xlabel('Request Number')
plt.ylabel('Connect Time')
df.sort_values(by='Connect',inplace=True, ascending=False)
plt.plot( range(0,1800),'Connect', data=df, marker='o', markerfacecolor='black', markersize=4, color='grey', linewidth=4)

# %%
#Elapsed
#Elapsed = RequestTime+ResponseTime
plt.xlabel('Request Number')
plt.ylabel('Elapsed')
plt.plot( range(0,1800),'elapsed', data=df, marker='o', markerfacecolor='white', markersize=4, color='black', linewidth=4)

# %%
#Connection Time and Latency
plt.xlabel('Request Number')
plt.plot(range(0,1800),'Latency', data=df, marker='o', markerfacecolor='blue', markersize=4, color='skyblue', linewidth=4)
plt.plot( 'Connect', '', data=df,  marker='', color='olive', linewidth=2)
#plt.plot( 'elapsed', '', data=df,  marker='', color='olive', linewidth=2)

# %%
#Connection Time and Latency
plt.xlabel('Request Number')
plt.plot(range(0,1800),'Connect', data=df, marker='o', markerfacecolor='blue', markersize=4, color='skyblue', linewidth=4)
plt.plot( 'elapsed', '', data=df,  marker='', color='olive', linewidth=2)
#plt.plot( 'elapsed', '', data=df,  marker='', color='olive', linewidth=2)

# %%
print(type(df['Latency'][0]))
print(type(df['Connect'][0]))
df['LatencyConnect'] = df['elapsed'] - df['Connect']
# Out:
# <class 'numpy.int64'>
# <class 'numpy.int64'>

# %%
plt.plot(range(0,1800),'LatencyConnect', data=df, marker='o', markerfacecolor='blue', markersize=4, color='skyblue', linewidth=4)
